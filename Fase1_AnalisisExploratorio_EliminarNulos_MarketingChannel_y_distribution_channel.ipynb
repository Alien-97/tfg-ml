# %%
import pandas as pd

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

with open('/content/drive/My Drive/TFG_AlienEmbarecRiadi/hotel_bookings_modified.csv') as csv_file:
  df = pd.read_csv(csv_file, delimiter=',')
  df.fillna({'distribution_channel':'Unknown'}, inplace=True)
  df.fillna({'market_segment':'Unknown'}, inplace=True)
  
  df.to_csv("/content/drive/My Drive/TFG_AlienEmbarecRiadi/hotel_bookings_modified.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-e1343ade0481> in <module>()
#       7 with open('/content/drive/My Drive/TFG_AlienEmbarecRiadi/hotel_bookings_modified.csv') as csv_file:
#       8   df = pd.read_csv(csv_file, delimiter=',')
# ----> 9   df.fillna({'distribution_channel':'Unknown'}, inPlace=True)
#      10   df.fillna({'market_segment':'Unknown'}, inPlace=True)
#      11   df.to_csv("/content/drive/My Drive/TFG_AlienEmbarecRiadi/hotel_bookings_modified.csv", index=False)
#
# TypeError: fillna() got an unexpected keyword argument 'inPlace'
